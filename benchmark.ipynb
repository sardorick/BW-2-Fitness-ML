# %%
# Importing needed packages
import pandas  as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OrdinalEncoder
from numpy import asarray
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
import time

# %%
#Getting data
df =pd.read_csv('five_sec')
df.head()
# Out:
#    dataset_5secondWindow.csv       id   time  activityrecognition#0  \
# 0                        0.0  16170.0   78.0                    NaN
# 1                        1.0  15871.0  145.0                    NaN
# 2                        2.0  16811.0  150.0                    NaN
# 3                        3.0  15831.0  105.0                    NaN
# 4                        4.0    876.0   77.0                    NaN
#
#    activityrecognition#1  android.sensor.accelerometer#mean  \
# 0                  100.0                           9.811476
# 1                  100.0                           9.939207
# 2                  100.0                           9.827178
# 3                   77.0                           9.673039
# 4                  100.0                           9.993466
#
#    android.sensor.accelerometer#min  android.sensor.accelerometer#max  \
# 0                          9.758895                          9.849411
# ...

# %%
df.head()
# Out:
#    dataset_5secondWindow.csv       id   time  activityrecognition#0  \
# 0                        0.0  16170.0   78.0                    NaN
# 1                        1.0  15871.0  145.0                    NaN
# 2                        2.0  16811.0  150.0                    NaN
# 3                        3.0  15831.0  105.0                    NaN
# 4                        4.0    876.0   77.0                    NaN
#
#    activityrecognition#1  android.sensor.accelerometer#mean  \
# 0                  100.0                           9.811476
# 1                  100.0                           9.939207
# 2                  100.0                           9.827178
# 3                   77.0                           9.673039
# 4                  100.0                           9.993466
#
#    android.sensor.accelerometer#min  android.sensor.accelerometer#max  \
# 0                          9.758895                          9.849411
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5894 entries, 0 to 5893
# Data columns (total 71 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   dataset_5secondWindow.csv                        5893 non-null   float64
#  1   id                                               5893 non-null   float64
#  2   time                                             5893 non-null   float64
#  3   activityrecognition#0                            0 non-null      float64
#  4   activityrecognition#1                            5893 non-null   float64
#  5   android.sensor.accelerometer#mean                5893 non-null   float64
#  6   android.sensor.accelerometer#min                 5893 non-null   float64
#  7   android.sensor.accelerometer#max                 5893 non-null   float64
#  8   android.sensor.accelerometer#std                 5893 non-null   float64
# ...

# %%
#counting nan in the data
df.isnull().sum().sort_values(ascending=False).head(30)
# Out:
# activityrecognition#0                              5894
# android.sensor.step_counter#std                    5662
# android.sensor.proximity#std                       5611
# android.sensor.proximity#max                       4775
# android.sensor.proximity#min                       4775
# android.sensor.proximity#mean                      4775
# android.sensor.pressure#std                        4766
# speed#std                                          4576
# android.sensor.step_counter#min                    4407
# android.sensor.step_counter#max                    4407
# android.sensor.step_counter#mean                   4407
# android.sensor.pressure#max                        3976
# android.sensor.pressure#min                        3976
# android.sensor.pressure#mean                       3976
# android.sensor.light#std                           3770
# speed#min                                          2374
# speed#mean                                         2374
# ...

# %%
#Dropping the columns with more than 1000 Nans
df = df.drop(['dataset_5secondWindow.csv', 'id','activityrecognition#0','android.sensor.step_counter#std','android.sensor.proximity#std','android.sensor.proximity#max','android.sensor.proximity#min','android.sensor.proximity#mean','android.sensor.pressure#std','speed#std','android.sensor.step_counter#min','android.sensor.step_counter#max','android.sensor.step_counter#mean','android.sensor.pressure#max','android.sensor.pressure#min','android.sensor.pressure#mean','android.sensor.light#std','speed#min','speed#mean','speed#max','sound#std','android.sensor.light#max','android.sensor.light#mean','android.sensor.light#min','user'], axis=1)

# %%
#recounting
print(df.isnull().sum().sort_values(ascending=False).head(30))
print(df.shape)
# Out:
# sound#max                                          995
# sound#min                                          995
# sound#mean                                         995
# android.sensor.magnetic_field_uncalibrated#std     807
# android.sensor.game_rotation_vector#std            801
# android.sensor.gyroscope_uncalibrated#max          800
# android.sensor.gyroscope_uncalibrated#std          800
# android.sensor.magnetic_field_uncalibrated#mean    800
# android.sensor.magnetic_field_uncalibrated#min     800
# android.sensor.magnetic_field_uncalibrated#max     800
# android.sensor.gyroscope_uncalibrated#min          800
# android.sensor.gyroscope_uncalibrated#mean         800
# android.sensor.game_rotation_vector#max            800
# android.sensor.game_rotation_vector#min            800
# android.sensor.game_rotation_vector#mean           800
# android.sensor.rotation_vector#std                 731
# android.sensor.rotation_vector#max                 722
# ...

# %%
#plotting nan values --> yellow is nan
plt.figure(figsize=(25, 12))
sns.heatmap(df.isnull(), yticklabels=False, cbar=False,cmap='viridis')
plt.show()

# %%
df = df.dropna(how='all')

# %%
#plotting nan values --> yellow is nan
plt.figure(figsize=(25, 12))
sns.heatmap(df.isnull(), yticklabels=False, cbar=False,cmap='viridis')
plt.show()

# %%
df.shape
# Out:
# (5893, 46)

# %%
df['target'].isnull().sum()
# Out:
# 0

# %%
#filling nan with 0
df = df.fillna(0)

# %%
#rechecking nans
df.isnull().sum().sort_values(ascending=False).head()
# Out:
# time                                      0
# android.sensor.orientation#mean           0
# android.sensor.linear_acceleration#std    0
# android.sensor.magnetic_field#mean        0
# android.sensor.magnetic_field#min         0
# dtype: int64

# %%
oe = OrdinalEncoder()
cd = asarray(df['target'])
df['target'] = oe.fit_transform(cd.reshape(-1,1))

# %%
#Splitting the data into train and test
X,y = df.drop(['target'], axis=1), df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
tree_classifiers= {
  "Decision Tree": DecisionTreeClassifier(),
  "Random Forest": RandomForestClassifier(),
  "Extra Trees":ExtraTreesClassifier()
   }

# %%
results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

for model_name, model in tree_classifiers.items():
    
    start_time = time.time()
    model.fit(X_train, y_train)
    total_time = time.time() - start_time
        
    pred = model.predict(X_test)
    
    results = results.append({"Model":    model_name,
                              "Accuracy": accuracy_score(y_test, pred)*100,
                              "Bal Acc.": balanced_accuracy_score(y_test, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
                              
                              
results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='Blues')
# Out:
# C:\Users\Abubakr\AppData\Local\Temp\ipykernel_17332\3920733270.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# C:\Users\Abubakr\AppData\Local\Temp\ipykernel_17332\3920733270.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# C:\Users\Abubakr\AppData\Local\Temp\ipykernel_17332\3920733270.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# <style type="text/css">
# #T_f2064_row0_col1, #T_f2064_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, Blues 97.0%, transparent 97.0%);
# }
# #T_f2064_row1_col1, #T_f2064_row1_col2 {
#   width: 10em;
# ...
