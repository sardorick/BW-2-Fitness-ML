# %%
import numpy as np
import pandas as pd

# %%
hdf =pd.read_csv('half_sec')

# %%
hdf.head(10)
# Out:
#    dataset_halfSecondWindow.csv        id  time  activityrecognition#0  \
# 0                           0.0  156661.0   3.0                    NaN
# 1                           1.0  156662.0   4.0                    NaN
# 2                           2.0  156663.0   5.0                    NaN
# 3                           3.0  156664.0   6.0                    NaN
# 4                           4.0  156665.0   7.0                    NaN
# 5                           5.0  156666.0   8.0                    NaN
# 6                           6.0  156667.0   9.0                    NaN
# 7                           7.0  156668.0  10.0                    NaN
# 8                           8.0  156669.0  11.0                    NaN
# 9                           9.0  156670.0  12.0                    NaN
#
#    activityrecognition#1  android.sensor.accelerometer#mean  \
# 0                   62.0                          10.053802
# 1                   62.0                          10.687402
# 2                   62.0                          11.816800
# 3                   62.0                           9.401312
# 4                   62.0                          10.389851
# 5                   62.0                          10.455521
# 6                   62.0                           9.957479
# 7                   62.0                           9.934564
# 8                   62.0                          10.164544
# 9                   62.0                           9.951800
#
#    android.sensor.accelerometer#min  android.sensor.accelerometer#max  \
# 0                          4.328630                         14.419712
# 1                          6.373194                         16.329818
# 2                          4.817410                         16.854629
# 3                          6.124588                         12.230792
# 4                          5.313790                         38.533453
# 5                          7.364041                         31.970115
# 6                          9.725805                         10.266291
# 7                          9.576659                         10.384592
# 8                          9.717692                         11.077734
# 9                          8.248045                         12.650428
#
#    android.sensor.accelerometer#std  android.sensor.game_rotation_vector#mean  \
# 0                          2.359507                                  0.629076
# 1                          2.912315                                  0.577839
# 2                          3.199759                                  0.651511
# 3                          1.572354                                  0.713226
# 4                          5.426978                                  0.707375
# 5                          2.855658                                  0.728942
# 6                          0.128728                                  0.720627
# 7                          0.180236                                  0.718975
# 8                          0.388465                                  0.729829
# 9                          1.147707                                  0.683296
#
#    ...  sound#mean  sound#min  sound#max  sound#std  speed#mean  speed#min  \
# 0  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 1  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 2  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 3  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 4  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 5  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 6  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 7  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 8  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 9  ...         NaN        NaN        NaN        NaN         NaN        NaN
#
#    speed#max  speed#std  target  user
# 0        NaN        NaN     Bus   U12
# 1        NaN        NaN     Bus   U12
# 2        NaN        NaN     Bus   U12
# 3        NaN        NaN     Bus   U12
# 4        NaN        NaN     Bus   U12
# 5        NaN        NaN     Bus   U12
# 6        NaN        NaN     Bus   U12
# 7        NaN        NaN     Bus   U12
# 8        NaN        NaN     Bus   U12
# 9        NaN        NaN     Bus   U12
#
# [10 rows x 71 columns]

# %%
print(hdf['user'].isna().sum())
print(hdf['target'].isna().sum())
# Out:
# 1
# 1

# %%
hdf =hdf.dropna(how='all')
print(hdf['user'].isna().sum())
print(hdf['target'].isna().sum())
# Out:
# 0
# 0

# %%
hdf['user'].value_counts()
# Out:
# U1     25700
# U12     9081
# U10     5717
# U7      4228
# U3      3522
# U6      3029
# U2      2897
# U4      2434
# U8      2229
# U11     1780
# U13      957
# U9       825
# U5       186
# Name: user, dtype: int64

# %%
hdf.isnull().sum().sort_values(ascending=False).head(30)
# Out:
# activityrecognition#0                             62585
# android.sensor.step_counter#std                   61698
# sound#std                                         61111
# speed#std                                         60894
# android.sensor.proximity#std                      59636
# android.sensor.pressure#std                       53653
# android.sensor.proximity#max                      50308
# android.sensor.proximity#mean                     50308
# android.sensor.proximity#min                      50308
# android.sensor.light#std                          49661
# android.sensor.step_counter#mean                  46974
# android.sensor.step_counter#min                   46974
# android.sensor.step_counter#max                   46974
# android.sensor.pressure#mean                      42214
# android.sensor.pressure#min                       42214
# android.sensor.pressure#max                       42214
# speed#mean                                        25920
# speed#min                                         25920
# speed#max                                         25920
# android.sensor.light#min                          16360
# android.sensor.light#max                          16360
# android.sensor.light#mean                         16360
# android.sensor.gravity#std                        12352
# android.sensor.magnetic_field_uncalibrated#std    12051
# android.sensor.linear_acceleration#std            12009
# sound#max                                         11658
# sound#min                                         11658
# sound#mean                                        11658
# android.sensor.game_rotation_vector#std           10662
# android.sensor.rotation_vector#std                 9891
# dtype: int64

# %%
hdf = hdf.drop(['android.sensor.accelerometer#min', 
        'android.sensor.accelerometer#max',
        'android.sensor.accelerometer#std',
        'android.sensor.game_rotation_vector#min',
        'android.sensor.game_rotation_vector#max',
        'android.sensor.game_rotation_vector#std',
        'android.sensor.gravity#min',
        'android.sensor.gravity#max',
        'android.sensor.gravity#std',
        'android.sensor.gravity#min',
        'android.sensor.gravity#max',
        'android.sensor.gravity#std',
        'android.sensor.gyroscope#min',
        'android.sensor.gyroscope#max', 
        'android.sensor.gyroscope#std',
        'android.sensor.gyroscope_uncalibrated#min',
       'android.sensor.gyroscope_uncalibrated#max',
       'android.sensor.gyroscope_uncalibrated#std',
       'android.sensor.light#min',
       'android.sensor.light#max', 
       'android.sensor.light#std',
       'android.sensor.linear_acceleration#min',
       'android.sensor.linear_acceleration#max',
       'android.sensor.linear_acceleration#std',
       'android.sensor.magnetic_field#min',
       'android.sensor.magnetic_field#max',
       'android.sensor.magnetic_field#std',
       'android.sensor.magnetic_field_uncalibrated#min',
       'android.sensor.magnetic_field_uncalibrated#max',
       'android.sensor.magnetic_field_uncalibrated#std',
       'android.sensor.orientation#min',
       'android.sensor.orientation#max',
       'android.sensor.orientation#std',
       'android.sensor.pressure#min',
       'android.sensor.pressure#max', 
       'android.sensor.pressure#std', 
       'android.sensor.proximity#min',
       'android.sensor.proximity#max', 
       'android.sensor.proximity#std',
       'android.sensor.rotation_vector#min',
       'android.sensor.rotation_vector#max',
       'android.sensor.rotation_vector#std',
       'android.sensor.step_counter#min',
       'android.sensor.step_counter#max', 
       'android.sensor.step_counter#std',
       'sound#min', 
       'sound#max', 
       'sound#std',
       'speed#min', 
       'speed#max', 
       'speed#std'],
       axis=1
        )

# %%
hdf['user'].value_counts()
# Out:
# U1     25700
# U12     9081
# U10     5717
# U7      4228
# U3      3522
# U6      3029
# U2      2897
# U4      2434
# U8      2229
# U11     1780
# U13      957
# U9       825
# U5       186
# Name: user, dtype: int64

# %%
hdf.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# activityrecognition#0                              62585
# android.sensor.proximity#mean                      50308
# android.sensor.step_counter#mean                   46974
# android.sensor.pressure#mean                       42214
# speed#mean                                         25920
# android.sensor.light#mean                          16360
# sound#mean                                         11658
# android.sensor.magnetic_field_uncalibrated#mean     8762
# android.sensor.game_rotation_vector#mean            8585
# android.sensor.gyroscope_uncalibrated#mean          8539
# android.sensor.rotation_vector#mean                 7840
# android.sensor.gyroscope#mean                       7711
# android.sensor.linear_acceleration#mean             5574
# android.sensor.gravity#mean                         5534
# android.sensor.orientation#mean                     5416
# android.sensor.magnetic_field#mean                  5381
# target                                                 0
# dataset_halfSecondWindow.csv                           0
# id                                                     0
# android.sensor.accelerometer#mean                      0
# dtype: int64

# %%
hdf['user'].value_counts()
# Out:
# U1     25700
# U12     9081
# U10     5717
# U7      4228
# U3      3522
# U6      3029
# U2      2897
# U4      2434
# U8      2229
# U11     1780
# U13      957
# U9       825
# U5       186
# Name: user, dtype: int64

# %%
hdf = hdf.drop(['dataset_halfSecondWindow.csv',
                'id',
                'activityrecognition#0',
                'android.sensor.proximity#mean',
                #'android.sensor.step_counter#mean',
                #'android.sensor.pressure#mean',
                'speed#mean',
                'android.sensor.light#mean',
                'sound#mean'
                ],
axis=1)

# %%
hdf.isnull().sum().sort_values(ascending=False)
# Out:
# android.sensor.step_counter#mean                   46974
# android.sensor.pressure#mean                       42214
# android.sensor.magnetic_field_uncalibrated#mean     8762
# android.sensor.game_rotation_vector#mean            8585
# android.sensor.gyroscope_uncalibrated#mean          8539
# android.sensor.rotation_vector#mean                 7840
# android.sensor.gyroscope#mean                       7711
# android.sensor.linear_acceleration#mean             5574
# android.sensor.gravity#mean                         5534
# android.sensor.orientation#mean                     5416
# android.sensor.magnetic_field#mean                  5381
# time                                                   0
# activityrecognition#1                                  0
# android.sensor.accelerometer#mean                      0
# target                                                 0
# user                                                   0
# dtype: int64

# %%
hdf.shape
# Out:
# (62585, 16)

# %%
hdf = hdf.loc[hdf['user']  == 'U4']

# %%
hdf.shape
# Out:
# (2434, 16)

# %%
hdf.head(20)
# Out:
#         time  activityrecognition#1  android.sensor.accelerometer#mean  \
# 12517   39.0                  100.0                           9.664274
# 12518  765.0                   92.0                           9.851328
# 12519  716.0                   92.0                           8.993620
# 12520  211.0                  100.0                           9.670509
# 12521  157.0                  100.0                           9.500139
# 12522  784.0                  100.0                          10.001708
# 12523  141.0                  100.0                          10.123752
# 12524  620.0                   92.0                           9.775273
# 12525  345.0                   92.0                           9.546082
# 12526   14.0                  100.0                          10.370607
# 12527  645.0                   92.0                           9.462491
# 12528  238.0                   92.0                           9.866321
# 12529  763.0                   92.0                           9.910858
# 12530  252.0                   92.0                           9.851888
# 12531  453.0                   92.0                           9.922064
# 12532   62.0                  100.0                           9.608348
# 12533  369.0                   92.0                           9.511258
# 12534  750.0                   92.0                           9.091188
# 12535  475.0                   92.0                           9.994044
# 12536  192.0                  100.0                           9.628996
#
#        android.sensor.game_rotation_vector#mean  android.sensor.gravity#mean  \
# 12517                                       NaN                     9.816152
# 12518                                       NaN                     9.809157
# 12519                                       NaN                     9.815745
# 12520                                       NaN                     9.812513
# 12521                                       NaN                     9.815225
# 12522                                       NaN                     9.809157
# 12523                                       NaN                     9.811435
# 12524                                       NaN                     9.813081
# 12525                                       NaN                     9.808022
# 12526                                       NaN                     9.818523
# 12527                                       NaN                     9.809704
# 12528                                       NaN                     9.812513
# 12529                                       NaN                     9.809157
# 12530                                       NaN                     9.812513
# 12531                                       NaN                     9.806376
# 12532                                       NaN                     9.818466
# 12533                                       NaN                     9.816464
# 12534                                       NaN                     9.809157
# 12535                                       NaN                     9.804778
# 12536                                       NaN                     9.817720
#
#        android.sensor.gyroscope#mean  \
# 12517                            NaN
# 12518                            NaN
# 12519                            NaN
# 12520                            NaN
# 12521                            NaN
# 12522                            NaN
# 12523                            NaN
# 12524                            NaN
# 12525                            NaN
# 12526                            NaN
# 12527                            NaN
# 12528                            NaN
# 12529                            NaN
# 12530                            NaN
# 12531                            NaN
# 12532                            NaN
# 12533                            NaN
# 12534                            NaN
# 12535                            NaN
# 12536                            NaN
#
#        android.sensor.gyroscope_uncalibrated#mean  \
# 12517                                         NaN
# 12518                                         NaN
# 12519                                         NaN
# 12520                                         NaN
# 12521                                         NaN
# 12522                                         NaN
# 12523                                         NaN
# 12524                                         NaN
# 12525                                         NaN
# 12526                                         NaN
# 12527                                         NaN
# 12528                                         NaN
# 12529                                         NaN
# 12530                                         NaN
# 12531                                         NaN
# 12532                                         NaN
# 12533                                         NaN
# 12534                                         NaN
# 12535                                         NaN
# 12536                                         NaN
#
#        android.sensor.linear_acceleration#mean  \
# 12517                                 0.417814
# 12518                                 1.358216
# 12519                                 0.204305
# 12520                                 0.417814
# 12521                                 0.468667
# 12522                                 0.830283
# 12523                                 0.468667
# 12524                                 1.411859
# 12525                                 0.748500
# 12526                                      NaN
# 12527                                 1.411859
# 12528                                 1.114707
# 12529                                 1.358216
# 12530                                 1.114707
# 12531                                 0.707472
# 12532                                 0.464891
# 12533                                 0.993539
# 12534                                 1.358216
# 12535                                 0.595569
# 12536                                 0.749243
#
#        android.sensor.magnetic_field#mean  \
# 12517                           54.795182
# 12518                           36.039940
# 12519                           55.319308
# 12520                           33.381272
# 12521                           36.208235
# 12522                           28.096365
# 12523                           47.646617
# 12524                           17.541884
# 12525                           44.929018
# 12526                           55.516817
# 12527                           17.754317
# 12528                           33.351034
# 12529                           35.186298
# 12530                           32.004578
# 12531                           32.374097
# 12532                           54.020496
# 12533                           43.169021
# 12534                           38.922671
# 12535                           31.039933
# 12536                           34.637771
#
#        android.sensor.magnetic_field_uncalibrated#mean  \
# 12517                                              NaN
# 12518                                              NaN
# 12519                                              NaN
# 12520                                              NaN
# 12521                                              NaN
# 12522                                              NaN
# 12523                                              NaN
# 12524                                              NaN
# 12525                                              NaN
# 12526                                              NaN
# 12527                                              NaN
# 12528                                              NaN
# 12529                                              NaN
# 12530                                              NaN
# 12531                                              NaN
# 12532                                              NaN
# 12533                                              NaN
# 12534                                              NaN
# 12535                                              NaN
# 12536                                              NaN
#
#        android.sensor.orientation#mean  android.sensor.pressure#mean  \
# 12517                       208.283340                           NaN
# 12518                       210.537019                           NaN
# 12519                       197.428379                           NaN
# 12520                       205.869228                           NaN
# 12521                       204.491906                           NaN
# 12522                       215.874174                           NaN
# 12523                       173.933452                           NaN
# 12524                       205.387291                           NaN
# 12525                       205.587333                           NaN
# 12526                       333.366751                           NaN
# 12527                       206.908782                           NaN
# 12528                       205.869228                           NaN
# 12529                       210.537019                           NaN
# 12530                       205.869228                           NaN
# 12531                       208.550308                           NaN
# 12532                       205.300422                           NaN
# 12533                       206.724769                           NaN
# 12534                       204.586338                           NaN
# 12535                       203.564117                           NaN
# 12536                       205.869228                           NaN
#
#        android.sensor.rotation_vector#mean  android.sensor.step_counter#mean  \
# 12517                                  NaN                               NaN
# 12518                                  NaN                               NaN
# 12519                                  NaN                               NaN
# 12520                                  NaN                               NaN
# 12521                                  NaN                               NaN
# 12522                                  NaN                               NaN
# 12523                                  NaN                               NaN
# 12524                                  NaN                               NaN
# 12525                                  NaN                               NaN
# 12526                                  NaN                               NaN
# 12527                                  NaN                               NaN
# 12528                                  NaN                               NaN
# 12529                                  NaN                               NaN
# 12530                                  NaN                               NaN
# 12531                                  NaN                               NaN
# 12532                                  NaN                               NaN
# 12533                                  NaN                               NaN
# 12534                                  NaN                               NaN
# 12535                                  NaN                               NaN
# 12536                                  NaN                               NaN
#
#       target user
# 12517    Car   U4
# 12518    Car   U4
# 12519    Car   U4
# 12520    Car   U4
# 12521    Car   U4
# 12522    Car   U4
# 12523    Car   U4
# 12524    Car   U4
# 12525    Car   U4
# 12526    Car   U4
# 12527    Car   U4
# 12528    Car   U4
# 12529    Car   U4
# 12530    Car   U4
# 12531    Car   U4
# 12532    Car   U4
# 12533    Car   U4
# 12534    Car   U4
# 12535    Car   U4
# 12536    Car   U4

# %%
act_df =hdf.loc[hdf['target'] == 'Walking']
act_df.shape
# Out:
# (1712, 16)

# %%
act_df.head(20)
# Out:
#          time  activityrecognition#1  android.sensor.accelerometer#mean  \
# 50068   357.0                  100.0                          12.090851
# 50069   655.0                  100.0                          10.005413
# 50070   125.0                  100.0                           8.857027
# 50071    32.0                  100.0                           9.349301
# 50072   515.0                  100.0                           9.864156
# 50073   537.0                  100.0                           7.893072
# 50074   184.0                  100.0                           9.963527
# 50075   933.0                  100.0                          10.161407
# 50076  1295.0                  100.0                           9.901312
# 50077   104.0                  100.0                           9.924247
# 50078   210.0                  100.0                          12.050060
# 50079   388.0                   92.0                          11.262767
# 50080  1133.0                  100.0                          10.083640
# 50081    43.0                  100.0                          13.065525
# 50082   141.0                  100.0                          11.400994
# 50083  1097.0                  100.0                           9.950971
# 50084   107.0                  100.0                          10.781367
# 50085   486.0                   87.0                           9.920577
# 50086   829.0                  100.0                          10.260537
# 50087   409.0                  100.0                           9.834181
#
#        android.sensor.game_rotation_vector#mean  android.sensor.gravity#mean  \
# 50068                                       NaN                     9.816964
# 50069                                       NaN                     9.796174
# 50070                                       NaN                     9.795994
# 50071                                       NaN                     9.799516
# 50072                                       NaN                     9.812485
# 50073                                       NaN                     9.817862
# 50074                                       NaN                     9.800708
# 50075                                       NaN                     9.801531
# 50076                                       NaN                     9.815670
# 50077                                       NaN                     9.794593
# 50078                                       NaN                     9.796023
# 50079                                       NaN                     9.792954
# 50080                                       NaN                     9.798607
# 50081                                       NaN                     9.799620
# 50082                                       NaN                     9.818986
# 50083                                       NaN                     9.799402
# 50084                                       NaN                     9.795994
# 50085                                       NaN                     9.810905
# 50086                                       NaN                     9.798456
# 50087                                       NaN                     9.816614
#
#        android.sensor.gyroscope#mean  \
# 50068                            NaN
# 50069                            NaN
# 50070                            NaN
# 50071                            NaN
# 50072                            NaN
# 50073                            NaN
# 50074                            NaN
# 50075                            NaN
# 50076                            NaN
# 50077                            NaN
# 50078                            NaN
# 50079                            NaN
# 50080                            NaN
# 50081                            NaN
# 50082                            NaN
# 50083                            NaN
# 50084                            NaN
# 50085                            NaN
# 50086                            NaN
# 50087                            NaN
#
#        android.sensor.gyroscope_uncalibrated#mean  \
# 50068                                         NaN
# 50069                                         NaN
# 50070                                         NaN
# 50071                                         NaN
# 50072                                         NaN
# 50073                                         NaN
# 50074                                         NaN
# 50075                                         NaN
# 50076                                         NaN
# 50077                                         NaN
# 50078                                         NaN
# 50079                                         NaN
# 50080                                         NaN
# 50081                                         NaN
# 50082                                         NaN
# 50083                                         NaN
# 50084                                         NaN
# 50085                                         NaN
# 50086                                         NaN
# 50087                                         NaN
#
#        android.sensor.linear_acceleration#mean  \
# 50068                                 5.292938
# 50069                                 0.697968
# 50070                                 2.798575
# 50071                                      NaN
# 50072                                 1.746488
# 50073                                 6.336039
# 50074                                 0.674998
# 50075                                 6.721845
# 50076                                 5.302497
# 50077                                 0.528217
# 50078                                 3.060944
# 50079                                 2.409108
# 50080                                 0.882279
# 50081                                 1.015698
# 50082                                 3.745620
# 50083                                 0.161733
# 50084                                 7.356413
# 50085                                 3.622603
# 50086                                 0.849718
# 50087                                 0.714257
#
#        android.sensor.magnetic_field#mean  \
# 50068                           35.007258
# 50069                           40.208532
# 50070                           40.672725
# 50071                           49.355597
# 50072                           42.935608
# 50073                           39.384477
# 50074                           41.651754
# 50075                           43.313649
# 50076                           42.202038
# 50077                           46.489696
# 50078                           39.376933
# 50079                           44.550459
# 50080                           46.557142
# 50081                           40.992314
# 50082                           39.492980
# 50083                           38.340817
# 50084                           43.492766
# 50085                           37.526339
# 50086                           40.018083
# 50087                           42.764515
#
#        android.sensor.magnetic_field_uncalibrated#mean  \
# 50068                                              NaN
# 50069                                              NaN
# 50070                                              NaN
# 50071                                              NaN
# 50072                                              NaN
# 50073                                              NaN
# 50074                                              NaN
# 50075                                              NaN
# 50076                                              NaN
# 50077                                              NaN
# 50078                                              NaN
# 50079                                              NaN
# 50080                                              NaN
# 50081                                              NaN
# 50082                                              NaN
# 50083                                              NaN
# 50084                                              NaN
# 50085                                              NaN
# 50086                                              NaN
# 50087                                              NaN
#
#        android.sensor.orientation#mean  android.sensor.pressure#mean  \
# 50068                        83.796578                           NaN
# 50069                       333.881135                           NaN
# 50070                       183.880083                           NaN
# 50071                       261.939856                           NaN
# 50072                       213.287269                           NaN
# 50073                        93.757597                           NaN
# 50074                        95.954536                           NaN
# 50075                       186.303254                           NaN
# 50076                       121.621922                           NaN
# 50077                        80.346304                           NaN
# 50078                       319.822966                           NaN
# 50079                       378.449828                           NaN
# 50080                       350.331795                           NaN
# 50081                       320.804045                           NaN
# 50082                       100.895171                           NaN
# 50083                       218.118202                           NaN
# 50084                       174.102396                           NaN
# 50085                        43.802825                           NaN
# 50086                       335.763818                           NaN
# 50087                       351.661461                           NaN
#
#        android.sensor.rotation_vector#mean  android.sensor.step_counter#mean  \
# 50068                                  NaN                               NaN
# 50069                                  NaN                               NaN
# 50070                                  NaN                               NaN
# 50071                                  NaN                               NaN
# 50072                                  NaN                               NaN
# 50073                                  NaN                               NaN
# 50074                                  NaN                               NaN
# 50075                                  NaN                               NaN
# 50076                                  NaN                               NaN
# 50077                                  NaN                               NaN
# 50078                                  NaN                               NaN
# 50079                                  NaN                               NaN
# 50080                                  NaN                               NaN
# 50081                                  NaN                               NaN
# 50082                                  NaN                               NaN
# 50083                                  NaN                               NaN
# 50084                                  NaN                               NaN
# 50085                                  NaN                               NaN
# 50086                                  NaN                               NaN
# 50087                                  NaN                               NaN
#
#         target user
# 50068  Walking   U4
# 50069  Walking   U4
# 50070  Walking   U4
# 50071  Walking   U4
# 50072  Walking   U4
# 50073  Walking   U4
# 50074  Walking   U4
# 50075  Walking   U4
# 50076  Walking   U4
# 50077  Walking   U4
# 50078  Walking   U4
# 50079  Walking   U4
# 50080  Walking   U4
# 50081  Walking   U4
# 50082  Walking   U4
# 50083  Walking   U4
# 50084  Walking   U4
# 50085  Walking   U4
# 50086  Walking   U4
# 50087  Walking   U4
