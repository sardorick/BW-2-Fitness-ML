# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import OrdinalEncoder
from numpy import asarray

from sklearn.linear_model  import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier

import time
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score

# %%
hdf =pd.read_csv('half_sec')

# %%
hdf.head(10)
# Out:
#    dataset_halfSecondWindow.csv        id  time  activityrecognition#0  \
# 0                           0.0  156661.0   3.0                    NaN
# 1                           1.0  156662.0   4.0                    NaN
# 2                           2.0  156663.0   5.0                    NaN
# 3                           3.0  156664.0   6.0                    NaN
# 4                           4.0  156665.0   7.0                    NaN
# 5                           5.0  156666.0   8.0                    NaN
# 6                           6.0  156667.0   9.0                    NaN
# 7                           7.0  156668.0  10.0                    NaN
# 8                           8.0  156669.0  11.0                    NaN
# 9                           9.0  156670.0  12.0                    NaN
#
#    activityrecognition#1  android.sensor.accelerometer#mean  \
# 0                   62.0                          10.053802
# 1                   62.0                          10.687402
# 2                   62.0                          11.816800
# 3                   62.0                           9.401312
# 4                   62.0                          10.389851
# 5                   62.0                          10.455521
# 6                   62.0                           9.957479
# 7                   62.0                           9.934564
# 8                   62.0                          10.164544
# 9                   62.0                           9.951800
#
#    android.sensor.accelerometer#min  android.sensor.accelerometer#max  \
# 0                          4.328630                         14.419712
# 1                          6.373194                         16.329818
# 2                          4.817410                         16.854629
# 3                          6.124588                         12.230792
# 4                          5.313790                         38.533453
# 5                          7.364041                         31.970115
# 6                          9.725805                         10.266291
# 7                          9.576659                         10.384592
# 8                          9.717692                         11.077734
# 9                          8.248045                         12.650428
#
#    android.sensor.accelerometer#std  android.sensor.game_rotation_vector#mean  \
# 0                          2.359507                                  0.629076
# 1                          2.912315                                  0.577839
# 2                          3.199759                                  0.651511
# 3                          1.572354                                  0.713226
# 4                          5.426978                                  0.707375
# 5                          2.855658                                  0.728942
# 6                          0.128728                                  0.720627
# 7                          0.180236                                  0.718975
# 8                          0.388465                                  0.729829
# 9                          1.147707                                  0.683296
#
#    ...  sound#mean  sound#min  sound#max  sound#std  speed#mean  speed#min  \
# 0  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 1  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 2  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 3  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 4  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 5  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 6  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 7  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 8  ...         NaN        NaN        NaN        NaN         NaN        NaN
# 9  ...         NaN        NaN        NaN        NaN         NaN        NaN
#
#    speed#max  speed#std  target  user
# 0        NaN        NaN     Bus   U12
# 1        NaN        NaN     Bus   U12
# 2        NaN        NaN     Bus   U12
# 3        NaN        NaN     Bus   U12
# 4        NaN        NaN     Bus   U12
# 5        NaN        NaN     Bus   U12
# 6        NaN        NaN     Bus   U12
# 7        NaN        NaN     Bus   U12
# 8        NaN        NaN     Bus   U12
# 9        NaN        NaN     Bus   U12
#
# [10 rows x 71 columns]

# %%
print(hdf['user'].isna().sum())
print(hdf['target'].isna().sum())
# Out:
# 1
# 1

# %%
hdf =hdf.dropna(how='all')
print(hdf['user'].isna().sum())
print(hdf['target'].isna().sum())
# Out:
# 0
# 0

# %%
hdf.isnull().sum().sort_values(ascending=False).head(30)
# Out:
# activityrecognition#0                             62585
# android.sensor.step_counter#std                   61698
# sound#std                                         61111
# speed#std                                         60894
# android.sensor.proximity#std                      59636
# android.sensor.pressure#std                       53653
# android.sensor.proximity#max                      50308
# android.sensor.proximity#mean                     50308
# android.sensor.proximity#min                      50308
# android.sensor.light#std                          49661
# android.sensor.step_counter#mean                  46974
# android.sensor.step_counter#min                   46974
# android.sensor.step_counter#max                   46974
# android.sensor.pressure#mean                      42214
# android.sensor.pressure#min                       42214
# android.sensor.pressure#max                       42214
# speed#mean                                        25920
# speed#min                                         25920
# speed#max                                         25920
# android.sensor.light#min                          16360
# android.sensor.light#max                          16360
# android.sensor.light#mean                         16360
# android.sensor.gravity#std                        12352
# android.sensor.magnetic_field_uncalibrated#std    12051
# android.sensor.linear_acceleration#std            12009
# sound#max                                         11658
# sound#min                                         11658
# sound#mean                                        11658
# android.sensor.game_rotation_vector#std           10662
# android.sensor.rotation_vector#std                 9891
# dtype: int64

# %%
hdf.columns
# Out:
# Index(['dataset_halfSecondWindow.csv', 'id', 'time', 'activityrecognition#0',
#        'activityrecognition#1', 'android.sensor.accelerometer#mean',
#        'android.sensor.accelerometer#min', 'android.sensor.accelerometer#max',
#        'android.sensor.accelerometer#std',
#        'android.sensor.game_rotation_vector#mean',
#        'android.sensor.game_rotation_vector#min',
#        'android.sensor.game_rotation_vector#max',
#        'android.sensor.game_rotation_vector#std',
#        'android.sensor.gravity#mean', 'android.sensor.gravity#min',
#        'android.sensor.gravity#max', 'android.sensor.gravity#std',
#        'android.sensor.gyroscope#mean', 'android.sensor.gyroscope#min',
#        'android.sensor.gyroscope#max', 'android.sensor.gyroscope#std',
#        'android.sensor.gyroscope_uncalibrated#mean',
#        'android.sensor.gyroscope_uncalibrated#min',
#        'android.sensor.gyroscope_uncalibrated#max',
#        'android.sensor.gyroscope_uncalibrated#std',
#        'android.sensor.light#mean', 'android.sensor.light#min',
#        'android.sensor.light#max', 'android.sensor.light#std',
#        'android.sensor.linear_acceleration#mean',
#        'android.sensor.linear_acceleration#min',
#        'android.sensor.linear_acceleration#max',
#        'android.sensor.linear_acceleration#std',
#        'android.sensor.magnetic_field#mean',
#        'android.sensor.magnetic_field#min',
#        'android.sensor.magnetic_field#max',
#        'android.sensor.magnetic_field#std',
#        'android.sensor.magnetic_field_uncalibrated#mean',
#        'android.sensor.magnetic_field_uncalibrated#min',
#        'android.sensor.magnetic_field_uncalibrated#max',
#        'android.sensor.magnetic_field_uncalibrated#std',
#        'android.sensor.orientation#mean', 'android.sensor.orientation#min',
#        'android.sensor.orientation#max', 'android.sensor.orientation#std',
#        'android.sensor.pressure#mean', 'android.sensor.pressure#min',
#        'android.sensor.pressure#max', 'android.sensor.pressure#std',
#        'android.sensor.proximity#mean', 'android.sensor.proximity#min',
#        'android.sensor.proximity#max', 'android.sensor.proximity#std',
#        'android.sensor.rotation_vector#mean',
#        'android.sensor.rotation_vector#min',
#        'android.sensor.rotation_vector#max',
#        'android.sensor.rotation_vector#std',
#        'android.sensor.step_counter#mean', 'android.sensor.step_counter#min',
#        'android.sensor.step_counter#max', 'android.sensor.step_counter#std',
#        'sound#mean', 'sound#min', 'sound#max', 'sound#std', 'speed#mean',
#        'speed#min', 'speed#max', 'speed#std', 'target', 'user'],
#       dtype='object')

# %%
hdf = hdf.drop(['android.sensor.accelerometer#min', 
        'android.sensor.accelerometer#max',
        'android.sensor.accelerometer#std',
        'android.sensor.game_rotation_vector#min',
        'android.sensor.game_rotation_vector#max',
        'android.sensor.game_rotation_vector#std',
        'android.sensor.gravity#min',
        'android.sensor.gravity#max',
        'android.sensor.gravity#std',
        'android.sensor.gravity#min',
        'android.sensor.gravity#max',
        'android.sensor.gravity#std',
        'android.sensor.gyroscope#min',
        'android.sensor.gyroscope#max', 
        'android.sensor.gyroscope#std',
        'android.sensor.gyroscope_uncalibrated#min',
       'android.sensor.gyroscope_uncalibrated#max',
       'android.sensor.gyroscope_uncalibrated#std',
       'android.sensor.light#min',
       'android.sensor.light#max', 
       'android.sensor.light#std',
       'android.sensor.linear_acceleration#min',
       'android.sensor.linear_acceleration#max',
       'android.sensor.linear_acceleration#std',
       'android.sensor.magnetic_field#min',
       'android.sensor.magnetic_field#max',
       'android.sensor.magnetic_field#std',
       'android.sensor.magnetic_field_uncalibrated#min',
       'android.sensor.magnetic_field_uncalibrated#max',
       'android.sensor.magnetic_field_uncalibrated#std',
       'android.sensor.orientation#min',
       'android.sensor.orientation#max',
       'android.sensor.orientation#std',
       'android.sensor.pressure#min',
       'android.sensor.pressure#max', 
       'android.sensor.pressure#std', 
       'android.sensor.proximity#min',
       'android.sensor.proximity#max', 
       'android.sensor.proximity#std',
       'android.sensor.rotation_vector#min',
       'android.sensor.rotation_vector#max',
       'android.sensor.rotation_vector#std',
       'android.sensor.step_counter#min',
       'android.sensor.step_counter#max', 
       'android.sensor.step_counter#std',
       'sound#min', 
       'sound#max', 
       'sound#std',
       'speed#min', 
       'speed#max', 
       'speed#std'],
       axis=1
        )

# %%
hdf.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# activityrecognition#0                              62585
# android.sensor.proximity#mean                      50308
# android.sensor.step_counter#mean                   46974
# android.sensor.pressure#mean                       42214
# speed#mean                                         25920
# android.sensor.light#mean                          16360
# sound#mean                                         11658
# android.sensor.magnetic_field_uncalibrated#mean     8762
# android.sensor.game_rotation_vector#mean            8585
# android.sensor.gyroscope_uncalibrated#mean          8539
# android.sensor.rotation_vector#mean                 7840
# android.sensor.gyroscope#mean                       7711
# android.sensor.linear_acceleration#mean             5574
# android.sensor.gravity#mean                         5534
# android.sensor.orientation#mean                     5416
# android.sensor.magnetic_field#mean                  5381
# target                                                 0
# dataset_halfSecondWindow.csv                           0
# id                                                     0
# android.sensor.accelerometer#mean                      0
# dtype: int64

# %%
hdf = hdf.drop(['dataset_halfSecondWindow.csv',
                'id',
                'activityrecognition#0',
                'android.sensor.proximity#mean',
                #'android.sensor.step_counter#mean',
                #'android.sensor.pressure#mean',
                'speed#mean',
                'android.sensor.light#mean',
                'sound#mean'
                ],
axis=1)

# %%
hdf.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# android.sensor.step_counter#mean                   46974
# android.sensor.pressure#mean                       42214
# android.sensor.magnetic_field_uncalibrated#mean     8762
# android.sensor.game_rotation_vector#mean            8585
# android.sensor.gyroscope_uncalibrated#mean          8539
# android.sensor.rotation_vector#mean                 7840
# android.sensor.gyroscope#mean                       7711
# android.sensor.linear_acceleration#mean             5574
# android.sensor.gravity#mean                         5534
# android.sensor.orientation#mean                     5416
# android.sensor.magnetic_field#mean                  5381
# time                                                   0
# activityrecognition#1                                  0
# android.sensor.accelerometer#mean                      0
# target                                                 0
# user                                                   0
# dtype: int64

# %%
hdf['android.sensor.step_counter#mean'] = hdf['android.sensor.step_counter#mean'].fillna('zero')
hdf['android.sensor.pressure#mean'] = hdf['android.sensor.pressure#mean'].fillna('zero')

# %%
hdf.head()
# Out:
#    time  activityrecognition#1  android.sensor.accelerometer#mean  \
# 0   3.0                   62.0                          10.053802
# 1   4.0                   62.0                          10.687402
# 2   5.0                   62.0                          11.816800
# 3   6.0                   62.0                           9.401312
# 4   7.0                   62.0                          10.389851
#
#    android.sensor.game_rotation_vector#mean  android.sensor.gravity#mean  \
# 0                                  0.629076                     9.806645
# 1                                  0.577839                     9.806640
# 2                                  0.651511                     9.806636
# 3                                  0.713226                     9.806635
# 4                                  0.707375                     9.806633
#
#    android.sensor.gyroscope#mean  android.sensor.gyroscope_uncalibrated#mean  \
# 0                       3.268103                                    3.278420
# 1                       3.388659                                    3.401418
# 2                       2.458691                                    2.452535
# 3                       1.275368                                    1.271005
# 4                       2.143492                                    2.152290
#
#    android.sensor.linear_acceleration#mean  \
# 0                                 3.955144
# 1                                 4.679740
# 2                                 4.248316
# 3                                 2.420904
# 4                                 3.961614
#
#    android.sensor.magnetic_field#mean  \
# 0                           26.294306
# 1                           26.295125
# 2                           27.048843
# 3                           25.878591
# 4                           25.599663
#
#    android.sensor.magnetic_field_uncalibrated#mean  \
# 0                                        38.660465
# 1                                        61.175710
# 2                                        72.826001
# 3                                        69.046004
# 4                                        69.424097
#
#    android.sensor.orientation#mean android.sensor.pressure#mean  \
# 0                        69.212414                  1009.638535
# 1                       147.052105                   1009.63851
# 2                       138.203285                  1009.589363
# 3                       147.486429                   1009.55217
# 4                       142.051738                   1009.55907
#
#    android.sensor.rotation_vector#mean android.sensor.step_counter#mean  \
# 0                             0.551880                           1809.0
# 1                             0.943359                           1809.0
# 2                             0.943879                           1809.0
# 3                             0.911758                           1809.0
# 4                             0.926211                           1809.0
#
#   target user
# 0    Bus  U12
# 1    Bus  U12
# 2    Bus  U12
# 3    Bus  U12
# 4    Bus  U12

# %%
hdf = hdf.dropna()

# %%
hdf.replace('zero',0, inplace=True)

# %%
hdf['user'].value_counts()
# Out:
# U1     25590
# U12     8951
# U10     5616
# U7      4044
# U3      3476
# U2      2866
# U11     1767
# U13      932
# U5       168
# Name: user, dtype: int64

# %%
hdf = hdf.sort_values(by='user')
hdf.reset_index(inplace=True)
hdf = hdf.drop(['index','user'], axis=1)
print(hdf.shape)
# Out:
# (53410, 15)

# %%
hdf.head()
# Out:
#      time  activityrecognition#1  android.sensor.accelerometer#mean  \
# 0   630.0                  100.0                          15.892297
# 1  3083.0                  100.0                          10.053232
# 2  5916.0                  100.0                          10.310094
# 3   264.0                  100.0                          10.479919
# 4  4642.0                  100.0                           9.856734
#
#    android.sensor.game_rotation_vector#mean  android.sensor.gravity#mean  \
# 0                                  0.838142                     9.806650
# 1                                  0.961465                     9.806651
# 2                                  0.487907                     9.806650
# 3                                  0.527317                     9.806650
# 4                                  0.450574                     9.806650
#
#    android.sensor.gyroscope#mean  android.sensor.gyroscope_uncalibrated#mean  \
# 0                       1.376634                                    2.859511
# 1                       0.019157                                    0.037881
# 2                       0.013922                                    0.036733
# 3                       0.029289                                    0.062155
# 4                       0.004632                                    0.031634
#
#    android.sensor.linear_acceleration#mean  \
# 0                                 1.815098
# 1                                 0.623998
# 2                                 0.646327
# 3                                 0.479445
# 4                                 0.077099
#
#    android.sensor.magnetic_field#mean  \
# 0                           41.889569
# 1                           78.087895
# 2                           59.250408
# 3                           81.056848
# 4                           57.389277
#
#    android.sensor.magnetic_field_uncalibrated#mean  \
# 0                                       163.965260
# 1                                       166.663579
# 2                                       164.095763
# 3                                       166.285917
# 4                                       164.763451
#
#    android.sensor.orientation#mean  android.sensor.pressure#mean  \
# 0                       165.396180                           0.0
# 1                        40.576032                           0.0
# 2                        58.024045                           0.0
# 3                        39.388573                           0.0
# 4                        53.410119                           0.0
#
#    android.sensor.rotation_vector#mean  android.sensor.step_counter#mean  \
# 0                             0.994523                             542.0
# 1                             0.369938                               0.0
# 2                             0.523054                               0.0
# 3                             0.342089                               0.0
# 4                             0.471094                               0.0
#
#     target
# 0  Walking
# 1      Car
# 2      Car
# 3      Car
# 4      Car

# %%
hdf.replace('Bus','0',inplace=True)
hdf.replace('Car','0',inplace=True)
hdf.replace('Still','0',inplace=True)
hdf.replace('Train','0',inplace=True)
hdf.replace('Walking','1',inplace=True)

# %%
hdf['target'].value_counts()
# Out:
# 0    43331
# 1    10079
# Name: target, dtype: int64

# %%
hdf['target'] = hdf['target'].astype('float')

# %%
X,y = hdf.drop(['target'], axis=1), hdf['target']

# %%
data_test = hdf.iloc[:25700, :]
data_train = hdf.iloc[25700: , :]

# %%
X_train = data_train.iloc[:,:14]
y_train = data_train.iloc[:, 14:]

X_test = data_test.iloc[:, :14]
y_test = data_test.iloc[:, 14:]

# %%
y_test.value_counts()
# Out:
# target
# 0.0       20884
# 1.0        4816
# dtype: int64

# %%
tree_classifiers= {
  "GBM": GradientBoostingClassifier(),
  "Logistic regression": LogisticRegression(),
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees":ExtraTreesClassifier(),
  "Random Forest": RandomForestClassifier()
}

# %%
results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

for model_name, model in tree_classifiers.items():
    
    start_time = time.time()
    model.fit(X_train, y_train)
    total_time = time.time() - start_time
        
    pred = model.predict(X_test)
    
    results = results.append({"Model":    model_name,
                              "Accuracy": accuracy_score(y_test, pred)*100,
                              "Bal Acc.": balanced_accuracy_score(y_test, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
                              
                              
results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='Blues')
# Out:
# c:\Users\Abubakr\Anaconda3\envs\ai\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Abubakr\AppData\Local\Temp\ipykernel_9732\3920733270.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# c:\Users\Abubakr\Anaconda3\envs\ai\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Abubakr\Anaconda3\envs\ai\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Abubakr\AppData\Local\Temp\ipykernel_9732\3920733270.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# C:\Users\Abubakr\AppData\Local\Temp\ipykernel_9732\3920733270.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# C:\Users\Abubakr\AppData\Local\Temp\ipykernel_9732\3920733270.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# C:\Users\Abubakr\AppData\Local\Temp\ipykernel_9732\3920733270.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# C:\Users\Abubakr\AppData\Local\Temp\ipykernel_9732\3920733270.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# C:\Users\Abubakr\AppData\Local\Temp\ipykernel_9732\3920733270.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model":    model_name,
# <style type="text/css">
# #T_d7eb3_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Blues 98.1%, transparent 98.1%);
# }
# #T_d7eb3_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, Blues 95.4%, transparent 95.4%);
# }
# #T_d7eb3_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Blues 96.3%, transparent 96.3%);
# }
# #T_d7eb3_row1_col2, #T_d7eb3_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, Blues 90.4%, transparent 90.4%);
# }
# #T_d7eb3_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Blues 96.1%, transparent 96.1%);
# }
# #T_d7eb3_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Blues 83.1%, transparent 83.1%);
# }
# #T_d7eb3_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, Blues 63.7%, transparent 63.7%);
# }
# #T_d7eb3_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Blues 81.3%, transparent 81.3%);
# }
# #T_d7eb3_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, Blues 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_d7eb3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7eb3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d7eb3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d7eb3_level0_col2" class="col_heading level0 col2" >Bal Acc.</th>
#       <th id="T_d7eb3_level0_col3" class="col_heading level0 col3" >Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7eb3_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d7eb3_row0_col0" class="data row0 col0" >GBM</td>
#       <td id="T_d7eb3_row0_col1" class="data row0 col1" >98.101167</td>
#       <td id="T_d7eb3_row0_col2" class="data row0 col2" >95.420816</td>
#       <td id="T_d7eb3_row0_col3" class="data row0 col3" >14.298695</td>
#     </tr>
#     <tr>
#       <th id="T_d7eb3_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d7eb3_row1_col0" class="data row1 col0" >Random Forest</td>
#       <td id="T_d7eb3_row1_col1" class="data row1 col1" >96.264591</td>
#       <td id="T_d7eb3_row1_col2" class="data row1 col2" >90.376702</td>
#       <td id="T_d7eb3_row1_col3" class="data row1 col3" >7.431181</td>
#     </tr>
#     <tr>
#       <th id="T_d7eb3_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d7eb3_row2_col0" class="data row2 col0" >Extra Trees</td>
#       <td id="T_d7eb3_row2_col1" class="data row2 col1" >96.105058</td>
#       <td id="T_d7eb3_row2_col2" class="data row2 col2" >90.406346</td>
#       <td id="T_d7eb3_row2_col3" class="data row2 col3" >2.251389</td>
#     </tr>
#     <tr>
#       <th id="T_d7eb3_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d7eb3_row3_col0" class="data row3 col0" >Decision Tree</td>
#       <td id="T_d7eb3_row3_col1" class="data row3 col1" >83.054475</td>
#       <td id="T_d7eb3_row3_col2" class="data row3 col2" >63.716582</td>
#       <td id="T_d7eb3_row3_col3" class="data row3 col3" >0.614697</td>
#     </tr>
#     <tr>
#       <th id="T_d7eb3_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d7eb3_row4_col0" class="data row4 col0" >Logistic regression</td>
#       <td id="T_d7eb3_row4_col1" class="data row4 col1" >81.260700</td>
#       <td id="T_d7eb3_row4_col2" class="data row4 col2" >50.000000</td>
#       <td id="T_d7eb3_row4_col3" class="data row4 col3" >0.490065</td>
#     </tr>
#   </tbody>
# </table>
